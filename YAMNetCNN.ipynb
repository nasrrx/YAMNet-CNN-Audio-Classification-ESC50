# %%
import torch
import numpy as np
from sklearn.model_selection import train_test_split
from torch.utils.data import TensorDataset, DataLoader, random_split

# === Load .npy files ===
X_seq = np.load("X_seq.npy")  # shape: (N, 100, 1024)
y_seq = np.load("y_seq.npy")  # shape: (N,)

# === Split into train/test (stratified) ===
X_train_np, X_test_np, y_train_np, y_test_np = train_test_split(
    X_seq, y_seq, test_size=0.2, stratify=y_seq, random_state=42
)

# === Convert to PyTorch tensors ===
X_train = torch.tensor(X_train_np, dtype=torch.float32)
y_train = torch.tensor(y_train_np, dtype=torch.long)
X_test = torch.tensor(X_test_np, dtype=torch.float32)
y_test = torch.tensor(y_test_np, dtype=torch.long)

# === Wrap in TensorDataset ===
train_dataset = TensorDataset(X_train, y_train)
test_dataset = TensorDataset(X_test, y_test)

# === Split train into train/val ===
val_ratio = 0.1
val_size = int(len(train_dataset) * val_ratio)
train_size = len(train_dataset) - val_size
train_set, val_set = random_split(train_dataset, [train_size, val_size])

# === Build DataLoaders ===
train_loader = DataLoader(train_set, batch_size=32, shuffle=True)
val_loader = DataLoader(val_set, batch_size=32)
test_loader = DataLoader(test_dataset, batch_size=32)

print("✅ DataLoaders ready:")
print(f"Train: {len(train_set)} | Val: {len(val_set)} | Test: {len(test_dataset)}")
# Out:
# ✅ DataLoaders ready:
# Train: 7727 | Val: 858 | Test: 2147

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class YAMNet1DCNN_Improved(nn.Module):
    def __init__(self, num_classes=57):
        super().__init__()
        self.conv1 = nn.Conv1d(1024, 512, kernel_size=5, padding=2)
        self.bn1 = nn.BatchNorm1d(512)
        self.pool1 = nn.MaxPool1d(2)

        self.conv2 = nn.Conv1d(512, 256, kernel_size=5, padding=2)
        self.bn2 = nn.BatchNorm1d(256)
        self.pool2 = nn.MaxPool1d(2)

        self.conv3 = nn.Conv1d(256, 128, kernel_size=3, padding=1)
        self.bn3 = nn.BatchNorm1d(128)

        self.global_pool = nn.AdaptiveAvgPool1d(1)
        self.dropout = nn.Dropout(0.75)  # Slightly higher for better regularization
        self.fc = nn.Linear(128, num_classes)

        self._init_weights()

    def _init_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv1d):
                nn.init.kaiming_normal_(m.weight, nonlinearity='relu')
                if m.bias is not None:
                    nn.init.zeros_(m.bias)
            elif isinstance(m, nn.Linear):
                nn.init.xavier_uniform_(m.weight)
                nn.init.zeros_(m.bias)

    def forward(self, x):
        x = x.permute(0, 2, 1)  # (B, 100, 1024) → (B, 1024, 100)
        x = self.pool1(F.gelu(self.bn1(self.conv1(x))))
        x = self.pool2(F.gelu(self.bn2(self.conv2(x))))
        x = F.gelu(self.bn3(self.conv3(x)))
        x = self.global_pool(x).squeeze(-1)
        x = self.dropout(x)
        return self.fc(x)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import os

class YAMNet1DCNN_Improved(nn.Module):
    def __init__(self, num_classes=57):
        super().__init__()
        self.conv1 = nn.Conv1d(1024, 512, kernel_size=5, padding=2)
        self.bn1 = nn.BatchNorm1d(512)
        self.pool1 = nn.MaxPool1d(2)

        self.conv2 = nn.Conv1d(512, 256, kernel_size=5, padding=2)
        self.bn2 = nn.BatchNorm1d(256)
        self.pool2 = nn.MaxPool1d(2)

        self.conv3 = nn.Conv1d(256, 128, kernel_size=3, padding=1)
        self.bn3 = nn.BatchNorm1d(128)

        self.global_pool = nn.AdaptiveAvgPool1d(1)
        self.dropout = nn.Dropout(0.75)  # Slightly higher for better regularization
        self.fc = nn.Linear(128, num_classes)

        self._init_weights()

    def _init_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv1d):
                nn.init.kaiming_normal_(m.weight, nonlinearity='relu')
                if m.bias is not None:
                    nn.init.zeros_(m.bias)
            elif isinstance(m, nn.Linear):
                nn.init.xavier_uniform_(m.weight)
                nn.init.zeros_(m.bias)

    def forward(self, x):
        x = x.permute(0, 2, 1)  # (B, 100, 1024) → (B, 1024, 100)
        x = self.pool1(F.gelu(self.bn1(self.conv1(x))))
        x = self.pool2(F.gelu(self.bn2(self.conv2(x))))
        x = F.gelu(self.bn3(self.conv3(x)))
        x = self.global_pool(x).squeeze(-1)
        x = self.dropout(x)
        return self.fc(x)


model = YAMNet1DCNN_Improved()
model.load_state_dict(torch.load("Best_Model.pt"))
model.eval()
torch.save(model, "yamnet_model_cnn.pt")  # saves model architecture + weights

example_input = torch.randn(1, 100, 1024)
traced_model = torch.jit.trace(model, example_input)
traced_model.save("Mobile_Audio_Classifier.pt")

# %%
# %pip install kivy soundfile torch

# %%
import torch
import torch.nn as nn
from sklearn.metrics import accuracy_score  # ✅ Needed for final test acc
from tqdm import tqdm  
import os

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = YAMNet1DCNN_Improved().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
criterion = nn.CrossEntropyLoss()

scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer,
    mode='max',
    factor=0.5,
    patience=4,
    min_lr=1e-6
)

best_val_acc = 0
patience = 200
no_improve_epochs = 0
saved_model_name = None

for epoch in range(1, 201):
    model.train()
    total_loss = 0
    correct = 0

    for xb, yb in train_loader:
        xb, yb = xb.to(device), yb.to(device)
        optimizer.zero_grad()
        preds = model(xb)
        loss = criterion(preds, yb)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
        correct += (preds.argmax(1) == yb).sum().item()

    train_acc = 100. * correct / len(train_loader.dataset)

    # 🔍 Validation
    model.eval()
    val_correct = 0
    val_total = 0
    with torch.no_grad():
        for xb, yb in val_loader:
            xb, yb = xb.to(device), yb.to(device)
            preds = model(xb)
            val_correct += (preds.argmax(1) == yb).sum().item()
            val_total += yb.size(0)
    val_acc = 100. * val_correct / val_total

    scheduler.step(val_acc)

    print(f"Epoch {epoch}: Loss={total_loss:.2f}, Train Acc={train_acc:.2f}%, Val Acc={val_acc:.2f}%")

    # ✅ Save model if val_acc >= 85 (allow duplicates with epoch number)
    if val_acc >= 85:
        val_str = f"{val_acc:.2f}".replace('.', '_')
        saved_model_name = f"Model_{val_str}_Epoch{epoch}.pt"
        torch.save(model.state_dict(), saved_model_name)
        print(f"✅ Saved model: {saved_model_name} (Val Acc: {val_acc:.2f}%)")

        if val_acc > best_val_acc:
            best_val_acc = val_acc
            no_improve_epochs = 0
    else:
        no_improve_epochs += 1
        if no_improve_epochs >= patience:
            print("⛔ Early stopping triggered.")
            break

model.eval()
all_preds = []
with torch.no_grad():
    for xb, _ in test_loader:
        xb = xb.to(device)
        preds = model(xb)
        all_preds.append(preds.cpu())

all_preds = torch.cat(all_preds).argmax(1).numpy()
acc = accuracy_score(y_test, all_preds)

print(f"\n✅ Final Test Accuracy: {acc * 100:.2f}%")
# Out:
# Epoch 1: Loss=530.70, Train Acc=53.81%, Val Acc=65.73%
# Epoch 2: Loss=325.42, Train Acc=69.43%, Val Acc=69.70%
# Epoch 3: Loss=260.73, Train Acc=73.48%, Val Acc=74.36%
# Epoch 4: Loss=223.67, Train Acc=77.21%, Val Acc=77.27%
# Epoch 5: Loss=192.62, Train Acc=79.69%, Val Acc=77.86%
# Epoch 6: Loss=166.74, Train Acc=82.36%, Val Acc=82.28%
# Epoch 7: Loss=152.99, Train Acc=84.03%, Val Acc=82.52%
# Epoch 8: Loss=132.73, Train Acc=86.55%, Val Acc=84.27%
# Epoch 9: Loss=121.98, Train Acc=87.77%, Val Acc=84.85%
# Epoch 10: Loss=115.19, Train Acc=88.25%, Val Acc=86.71%
# ✅ Saved model: Model_86_71_Epoch10.pt (Val Acc: 86.71%)
# Epoch 11: Loss=105.18, Train Acc=89.34%, Val Acc=86.36%
# ✅ Saved model: Model_86_36_Epoch11.pt (Val Acc: 86.36%)
# Epoch 12: Loss=93.01, Train Acc=90.40%, Val Acc=86.48%
# ✅ Saved model: Model_86_48_Epoch12.pt (Val Acc: 86.48%)
# Epoch 13: Loss=85.11, Train Acc=90.85%, Val Acc=87.30%
# ✅ Saved model: Model_87_30_Epoch13.pt (Val Acc: 87.30%)
# Epoch 14: Loss=82.15, Train Acc=91.29%, Val Acc=86.83%
# ✅ Saved model: Model_86_83_Epoch14.pt (Val Acc: 86.83%)
# Epoch 15: Loss=72.18, Train Acc=92.66%, Val Acc=86.36%
# ✅ Saved model: Model_86_36_Epoch15.pt (Val Acc: 86.36%)
# Epoch 16: Loss=70.25, Train Acc=92.53%, Val Acc=87.06%
# ✅ Saved model: Model_87_06_Epoch16.pt (Val Acc: 87.06%)
# Epoch 17: Loss=65.82, Train Acc=93.45%, Val Acc=86.95%
# ✅ Saved model: Model_86_95_Epoch17.pt (Val Acc: 86.95%)
# Epoch 18: Loss=56.81, Train Acc=94.19%, Val Acc=89.39%
# ✅ Saved model: Model_89_39_Epoch18.pt (Val Acc: 89.39%)
# Epoch 19: Loss=54.73, Train Acc=94.24%, Val Acc=87.06%
# ✅ Saved model: Model_87_06_Epoch19.pt (Val Acc: 87.06%)
# Epoch 20: Loss=52.44, Train Acc=94.60%, Val Acc=89.63%
# ✅ Saved model: Model_89_63_Epoch20.pt (Val Acc: 89.63%)
# Epoch 21: Loss=49.41, Train Acc=94.88%, Val Acc=86.71%
# ✅ Saved model: Model_86_71_Epoch21.pt (Val Acc: 86.71%)
# Epoch 22: Loss=46.98, Train Acc=95.15%, Val Acc=89.86%
# ✅ Saved model: Model_89_86_Epoch22.pt (Val Acc: 89.86%)
# Epoch 23: Loss=46.46, Train Acc=94.94%, Val Acc=89.28%
# ✅ Saved model: Model_89_28_Epoch23.pt (Val Acc: 89.28%)
# Epoch 24: Loss=47.83, Train Acc=94.88%, Val Acc=89.98%
# ✅ Saved model: Model_89_98_Epoch24.pt (Val Acc: 89.98%)
# Epoch 25: Loss=41.69, Train Acc=95.72%, Val Acc=89.86%
# ✅ Saved model: Model_89_86_Epoch25.pt (Val Acc: 89.86%)
# Epoch 26: Loss=38.17, Train Acc=95.92%, Val Acc=89.74%
# ✅ Saved model: Model_89_74_Epoch26.pt (Val Acc: 89.74%)
# Epoch 27: Loss=40.17, Train Acc=95.82%, Val Acc=88.93%
# ✅ Saved model: Model_88_93_Epoch27.pt (Val Acc: 88.93%)
# Epoch 28: Loss=37.78, Train Acc=95.99%, Val Acc=89.63%
# ✅ Saved model: Model_89_63_Epoch28.pt (Val Acc: 89.63%)
# Epoch 29: Loss=34.37, Train Acc=96.35%, Val Acc=89.63%
# ✅ Saved model: Model_89_63_Epoch29.pt (Val Acc: 89.63%)
# Epoch 30: Loss=32.53, Train Acc=96.49%, Val Acc=89.86%
# ✅ Saved model: Model_89_86_Epoch30.pt (Val Acc: 89.86%)
# Epoch 31: Loss=29.04, Train Acc=97.06%, Val Acc=90.21%
# ✅ Saved model: Model_90_21_Epoch31.pt (Val Acc: 90.21%)
# Epoch 32: Loss=33.79, Train Acc=96.34%, Val Acc=88.11%
# ✅ Saved model: Model_88_11_Epoch32.pt (Val Acc: 88.11%)
# Epoch 33: Loss=34.29, Train Acc=96.49%, Val Acc=89.98%
# ✅ Saved model: Model_89_98_Epoch33.pt (Val Acc: 89.98%)
# Epoch 34: Loss=30.89, Train Acc=96.60%, Val Acc=89.04%
# ✅ Saved model: Model_89_04_Epoch34.pt (Val Acc: 89.04%)
# Epoch 35: Loss=33.59, Train Acc=96.47%, Val Acc=89.86%
# ✅ Saved model: Model_89_86_Epoch35.pt (Val Acc: 89.86%)
# Epoch 36: Loss=28.92, Train Acc=96.82%, Val Acc=89.04%
# ✅ Saved model: Model_89_04_Epoch36.pt (Val Acc: 89.04%)
# Epoch 37: Loss=23.80, Train Acc=97.49%, Val Acc=89.28%
# ✅ Saved model: Model_89_28_Epoch37.pt (Val Acc: 89.28%)
# Epoch 38: Loss=25.42, Train Acc=97.33%, Val Acc=90.44%
# ✅ Saved model: Model_90_44_Epoch38.pt (Val Acc: 90.44%)
# Epoch 39: Loss=24.45, Train Acc=97.33%, Val Acc=88.81%
# ✅ Saved model: Model_88_81_Epoch39.pt (Val Acc: 88.81%)
# Epoch 40: Loss=23.61, Train Acc=97.53%, Val Acc=90.21%
# ✅ Saved model: Model_90_21_Epoch40.pt (Val Acc: 90.21%)
# Epoch 41: Loss=23.97, Train Acc=97.58%, Val Acc=89.16%
# ✅ Saved model: Model_89_16_Epoch41.pt (Val Acc: 89.16%)
# Epoch 42: Loss=21.59, Train Acc=97.59%, Val Acc=90.68%
# ✅ Saved model: Model_90_68_Epoch42.pt (Val Acc: 90.68%)
# Epoch 43: Loss=26.24, Train Acc=97.14%, Val Acc=91.72%
# ✅ Saved model: Model_91_72_Epoch43.pt (Val Acc: 91.72%)
# Epoch 44: Loss=20.56, Train Acc=97.92%, Val Acc=90.09%
# ✅ Saved model: Model_90_09_Epoch44.pt (Val Acc: 90.09%)
# Epoch 45: Loss=20.79, Train Acc=97.83%, Val Acc=91.72%
# ✅ Saved model: Model_91_72_Epoch45.pt (Val Acc: 91.72%)
# Epoch 46: Loss=16.33, Train Acc=98.18%, Val Acc=91.03%
# ✅ Saved model: Model_91_03_Epoch46.pt (Val Acc: 91.03%)
# Epoch 47: Loss=15.99, Train Acc=98.33%, Val Acc=90.56%
# ✅ Saved model: Model_90_56_Epoch47.pt (Val Acc: 90.56%)
# Epoch 48: Loss=17.13, Train Acc=98.20%, Val Acc=91.14%
# ✅ Saved model: Model_91_14_Epoch48.pt (Val Acc: 91.14%)
# Epoch 49: Loss=19.80, Train Acc=97.90%, Val Acc=89.51%
# ✅ Saved model: Model_89_51_Epoch49.pt (Val Acc: 89.51%)
# Epoch 50: Loss=20.86, Train Acc=97.89%, Val Acc=90.09%
# ✅ Saved model: Model_90_09_Epoch50.pt (Val Acc: 90.09%)
# Epoch 51: Loss=18.12, Train Acc=98.16%, Val Acc=90.21%
# ✅ Saved model: Model_90_21_Epoch51.pt (Val Acc: 90.21%)
# Epoch 52: Loss=15.65, Train Acc=98.23%, Val Acc=89.16%
# ✅ Saved model: Model_89_16_Epoch52.pt (Val Acc: 89.16%)
# Epoch 53: Loss=24.52, Train Acc=97.14%, Val Acc=89.63%
# ✅ Saved model: Model_89_63_Epoch53.pt (Val Acc: 89.63%)
# Epoch 54: Loss=16.58, Train Acc=98.19%, Val Acc=91.14%
# ✅ Saved model: Model_91_14_Epoch54.pt (Val Acc: 91.14%)
# Epoch 55: Loss=13.97, Train Acc=98.46%, Val Acc=90.79%
# ✅ Saved model: Model_90_79_Epoch55.pt (Val Acc: 90.79%)
# Epoch 56: Loss=19.06, Train Acc=98.10%, Val Acc=90.68%
# ✅ Saved model: Model_90_68_Epoch56.pt (Val Acc: 90.68%)
# Epoch 57: Loss=15.40, Train Acc=98.41%, Val Acc=91.14%
# ✅ Saved model: Model_91_14_Epoch57.pt (Val Acc: 91.14%)
# Epoch 58: Loss=13.87, Train Acc=98.49%, Val Acc=91.14%
# ✅ Saved model: Model_91_14_Epoch58.pt (Val Acc: 91.14%)
# Epoch 59: Loss=13.99, Train Acc=98.38%, Val Acc=90.56%
# ✅ Saved model: Model_90_56_Epoch59.pt (Val Acc: 90.56%)
# Epoch 60: Loss=8.49, Train Acc=99.11%, Val Acc=91.03%
# ✅ Saved model: Model_91_03_Epoch60.pt (Val Acc: 91.03%)
# Epoch 61: Loss=7.14, Train Acc=99.26%, Val Acc=92.54%
# ✅ Saved model: Model_92_54_Epoch61.pt (Val Acc: 92.54%)
# Epoch 62: Loss=7.85, Train Acc=99.24%, Val Acc=91.96%
# ✅ Saved model: Model_91_96_Epoch62.pt (Val Acc: 91.96%)
# Epoch 63: Loss=6.19, Train Acc=99.44%, Val Acc=92.54%
# ✅ Saved model: Model_92_54_Epoch63.pt (Val Acc: 92.54%)
# Epoch 64: Loss=6.50, Train Acc=99.39%, Val Acc=92.77%
# ✅ Saved model: Model_92_77_Epoch64.pt (Val Acc: 92.77%)
# Epoch 65: Loss=6.27, Train Acc=99.37%, Val Acc=91.84%
# ✅ Saved model: Model_91_84_Epoch65.pt (Val Acc: 91.84%)
# Epoch 66: Loss=6.82, Train Acc=99.30%, Val Acc=91.72%
# ✅ Saved model: Model_91_72_Epoch66.pt (Val Acc: 91.72%)
# Epoch 67: Loss=6.93, Train Acc=99.25%, Val Acc=91.61%
# ✅ Saved model: Model_91_61_Epoch67.pt (Val Acc: 91.61%)
# Epoch 68: Loss=7.14, Train Acc=99.31%, Val Acc=92.31%
# ✅ Saved model: Model_92_31_Epoch68.pt (Val Acc: 92.31%)
# Epoch 69: Loss=6.64, Train Acc=99.31%, Val Acc=91.84%
# ✅ Saved model: Model_91_84_Epoch69.pt (Val Acc: 91.84%)
# Epoch 70: Loss=6.15, Train Acc=99.31%, Val Acc=91.96%
# ✅ Saved model: Model_91_96_Epoch70.pt (Val Acc: 91.96%)
# Epoch 71: Loss=6.68, Train Acc=99.39%, Val Acc=91.61%
# ✅ Saved model: Model_91_61_Epoch71.pt (Val Acc: 91.61%)
# Epoch 72: Loss=7.49, Train Acc=99.33%, Val Acc=92.07%
# ✅ Saved model: Model_92_07_Epoch72.pt (Val Acc: 92.07%)
# Epoch 73: Loss=5.92, Train Acc=99.37%, Val Acc=91.72%
# ✅ Saved model: Model_91_72_Epoch73.pt (Val Acc: 91.72%)
# Epoch 74: Loss=5.66, Train Acc=99.42%, Val Acc=91.03%
# ✅ Saved model: Model_91_03_Epoch74.pt (Val Acc: 91.03%)
# Epoch 75: Loss=7.01, Train Acc=99.34%, Val Acc=92.07%
# ✅ Saved model: Model_92_07_Epoch75.pt (Val Acc: 92.07%)
# Epoch 76: Loss=8.93, Train Acc=99.17%, Val Acc=91.38%
# ✅ Saved model: Model_91_38_Epoch76.pt (Val Acc: 91.38%)
# Epoch 77: Loss=5.56, Train Acc=99.38%, Val Acc=91.72%
# ✅ Saved model: Model_91_72_Epoch77.pt (Val Acc: 91.72%)
# Epoch 78: Loss=5.96, Train Acc=99.35%, Val Acc=91.84%
# ✅ Saved model: Model_91_84_Epoch78.pt (Val Acc: 91.84%)
# Epoch 79: Loss=5.11, Train Acc=99.56%, Val Acc=91.49%
# ✅ Saved model: Model_91_49_Epoch79.pt (Val Acc: 91.49%)
# Epoch 80: Loss=5.57, Train Acc=99.43%, Val Acc=90.79%
# ✅ Saved model: Model_90_79_Epoch80.pt (Val Acc: 90.79%)
# Epoch 81: Loss=3.73, Train Acc=99.72%, Val Acc=91.96%
# ✅ Saved model: Model_91_96_Epoch81.pt (Val Acc: 91.96%)
# Epoch 82: Loss=3.68, Train Acc=99.73%, Val Acc=91.84%
# ✅ Saved model: Model_91_84_Epoch82.pt (Val Acc: 91.84%)
# Epoch 83: Loss=2.88, Train Acc=99.81%, Val Acc=91.38%
# ✅ Saved model: Model_91_38_Epoch83.pt (Val Acc: 91.38%)
# Epoch 84: Loss=3.04, Train Acc=99.73%, Val Acc=92.07%
# ✅ Saved model: Model_92_07_Epoch84.pt (Val Acc: 92.07%)
# Epoch 85: Loss=2.75, Train Acc=99.79%, Val Acc=91.96%
# ✅ Saved model: Model_91_96_Epoch85.pt (Val Acc: 91.96%)
# Epoch 86: Loss=3.06, Train Acc=99.75%, Val Acc=92.19%
# ✅ Saved model: Model_92_19_Epoch86.pt (Val Acc: 92.19%)
# Epoch 87: Loss=3.09, Train Acc=99.72%, Val Acc=92.31%
# ✅ Saved model: Model_92_31_Epoch87.pt (Val Acc: 92.31%)
# Epoch 88: Loss=2.62, Train Acc=99.79%, Val Acc=91.72%
# ✅ Saved model: Model_91_72_Epoch88.pt (Val Acc: 91.72%)
# Epoch 89: Loss=2.35, Train Acc=99.82%, Val Acc=91.72%
# ✅ Saved model: Model_91_72_Epoch89.pt (Val Acc: 91.72%)
# Epoch 90: Loss=2.53, Train Acc=99.81%, Val Acc=92.19%
# ✅ Saved model: Model_92_19_Epoch90.pt (Val Acc: 92.19%)
# Epoch 91: Loss=3.71, Train Acc=99.74%, Val Acc=91.61%
# ✅ Saved model: Model_91_61_Epoch91.pt (Val Acc: 91.61%)
# Epoch 92: Loss=2.92, Train Acc=99.77%, Val Acc=92.54%
# ✅ Saved model: Model_92_54_Epoch92.pt (Val Acc: 92.54%)
# Epoch 93: Loss=2.43, Train Acc=99.81%, Val Acc=92.89%
# ✅ Saved model: Model_92_89_Epoch93.pt (Val Acc: 92.89%)
# Epoch 94: Loss=2.43, Train Acc=99.83%, Val Acc=92.66%
# ✅ Saved model: Model_92_66_Epoch94.pt (Val Acc: 92.66%)
# Epoch 95: Loss=2.29, Train Acc=99.79%, Val Acc=92.19%
# ✅ Saved model: Model_92_19_Epoch95.pt (Val Acc: 92.19%)
# Epoch 96: Loss=1.99, Train Acc=99.86%, Val Acc=92.19%
# ✅ Saved model: Model_92_19_Epoch96.pt (Val Acc: 92.19%)
# Epoch 97: Loss=2.77, Train Acc=99.77%, Val Acc=92.54%
# ✅ Saved model: Model_92_54_Epoch97.pt (Val Acc: 92.54%)
# Epoch 98: Loss=2.48, Train Acc=99.79%, Val Acc=92.42%
# ✅ Saved model: Model_92_42_Epoch98.pt (Val Acc: 92.42%)
# Epoch 99: Loss=2.47, Train Acc=99.86%, Val Acc=91.14%
# ✅ Saved model: Model_91_14_Epoch99.pt (Val Acc: 91.14%)
# Epoch 100: Loss=2.52, Train Acc=99.82%, Val Acc=91.61%
# ✅ Saved model: Model_91_61_Epoch100.pt (Val Acc: 91.61%)
# Epoch 101: Loss=2.15, Train Acc=99.77%, Val Acc=91.49%
# ✅ Saved model: Model_91_49_Epoch101.pt (Val Acc: 91.49%)
# Epoch 102: Loss=2.07, Train Acc=99.84%, Val Acc=91.96%
# ✅ Saved model: Model_91_96_Epoch102.pt (Val Acc: 91.96%)
# Epoch 103: Loss=2.19, Train Acc=99.83%, Val Acc=92.42%
# ✅ Saved model: Model_92_42_Epoch103.pt (Val Acc: 92.42%)
# Epoch 104: Loss=1.73, Train Acc=99.92%, Val Acc=92.31%
# ✅ Saved model: Model_92_31_Epoch104.pt (Val Acc: 92.31%)
# Epoch 105: Loss=3.23, Train Acc=99.75%, Val Acc=92.19%
# ✅ Saved model: Model_92_19_Epoch105.pt (Val Acc: 92.19%)
# Epoch 106: Loss=2.50, Train Acc=99.75%, Val Acc=91.72%
# ✅ Saved model: Model_91_72_Epoch106.pt (Val Acc: 91.72%)
# Epoch 107: Loss=2.47, Train Acc=99.81%, Val Acc=92.07%
# ✅ Saved model: Model_92_07_Epoch107.pt (Val Acc: 92.07%)
# Epoch 108: Loss=2.20, Train Acc=99.84%, Val Acc=92.42%
# ✅ Saved model: Model_92_42_Epoch108.pt (Val Acc: 92.42%)
# Epoch 109: Loss=2.19, Train Acc=99.83%, Val Acc=92.31%
# ✅ Saved model: Model_92_31_Epoch109.pt (Val Acc: 92.31%)
# Epoch 110: Loss=1.34, Train Acc=99.94%, Val Acc=92.42%
# ✅ Saved model: Model_92_42_Epoch110.pt (Val Acc: 92.42%)
# Epoch 111: Loss=1.50, Train Acc=99.90%, Val Acc=92.54%
# ✅ Saved model: Model_92_54_Epoch111.pt (Val Acc: 92.54%)
# Epoch 112: Loss=1.50, Train Acc=99.90%, Val Acc=92.19%
# ✅ Saved model: Model_92_19_Epoch112.pt (Val Acc: 92.19%)
# Epoch 113: Loss=1.30, Train Acc=99.95%, Val Acc=92.77%
# ✅ Saved model: Model_92_77_Epoch113.pt (Val Acc: 92.77%)
# Epoch 114: Loss=1.62, Train Acc=99.84%, Val Acc=92.31%
# ✅ Saved model: Model_92_31_Epoch114.pt (Val Acc: 92.31%)
# Epoch 115: Loss=1.15, Train Acc=99.94%, Val Acc=92.42%
# ✅ Saved model: Model_92_42_Epoch115.pt (Val Acc: 92.42%)
# Epoch 116: Loss=1.24, Train Acc=99.92%, Val Acc=92.42%
# ✅ Saved model: Model_92_42_Epoch116.pt (Val Acc: 92.42%)
# Epoch 117: Loss=1.51, Train Acc=99.88%, Val Acc=92.31%
# ✅ Saved model: Model_92_31_Epoch117.pt (Val Acc: 92.31%)
# Epoch 118: Loss=1.17, Train Acc=99.94%, Val Acc=92.54%
# ✅ Saved model: Model_92_54_Epoch118.pt (Val Acc: 92.54%)
# Epoch 119: Loss=1.43, Train Acc=99.91%, Val Acc=92.42%
# ✅ Saved model: Model_92_42_Epoch119.pt (Val Acc: 92.42%)
# Epoch 120: Loss=1.31, Train Acc=99.92%, Val Acc=92.66%
# ✅ Saved model: Model_92_66_Epoch120.pt (Val Acc: 92.66%)
# Epoch 121: Loss=1.39, Train Acc=99.87%, Val Acc=91.72%
# ✅ Saved model: Model_91_72_Epoch121.pt (Val Acc: 91.72%)
# Epoch 122: Loss=1.13, Train Acc=99.94%, Val Acc=92.31%
# ✅ Saved model: Model_92_31_Epoch122.pt (Val Acc: 92.31%)
# Epoch 123: Loss=1.17, Train Acc=99.95%, Val Acc=92.66%
# ✅ Saved model: Model_92_66_Epoch123.pt (Val Acc: 92.66%)
# Epoch 124: Loss=1.25, Train Acc=99.91%, Val Acc=92.77%
# ✅ Saved model: Model_92_77_Epoch124.pt (Val Acc: 92.77%)
# Epoch 125: Loss=1.27, Train Acc=99.92%, Val Acc=92.54%
# ✅ Saved model: Model_92_54_Epoch125.pt (Val Acc: 92.54%)
# Epoch 126: Loss=1.42, Train Acc=99.90%, Val Acc=92.66%
# ✅ Saved model: Model_92_66_Epoch126.pt (Val Acc: 92.66%)
# Epoch 127: Loss=1.02, Train Acc=99.92%, Val Acc=92.31%
# ✅ Saved model: Model_92_31_Epoch127.pt (Val Acc: 92.31%)
# Epoch 128: Loss=0.97, Train Acc=99.95%, Val Acc=92.31%
# ✅ Saved model: Model_92_31_Epoch128.pt (Val Acc: 92.31%)
# Epoch 129: Loss=0.91, Train Acc=99.96%, Val Acc=92.54%
# ✅ Saved model: Model_92_54_Epoch129.pt (Val Acc: 92.54%)
# Epoch 130: Loss=1.02, Train Acc=99.92%, Val Acc=92.42%
# ✅ Saved model: Model_92_42_Epoch130.pt (Val Acc: 92.42%)
# Epoch 131: Loss=1.00, Train Acc=99.95%, Val Acc=92.66%
# ✅ Saved model: Model_92_66_Epoch131.pt (Val Acc: 92.66%)
# Epoch 132: Loss=0.92, Train Acc=99.97%, Val Acc=92.54%
# ✅ Saved model: Model_92_54_Epoch132.pt (Val Acc: 92.54%)
# Epoch 133: Loss=0.92, Train Acc=99.92%, Val Acc=92.42%
# ✅ Saved model: Model_92_42_Epoch133.pt (Val Acc: 92.42%)
# Epoch 134: Loss=0.82, Train Acc=99.96%, Val Acc=92.42%
# ✅ Saved model: Model_92_42_Epoch134.pt (Val Acc: 92.42%)
# Epoch 135: Loss=0.96, Train Acc=99.94%, Val Acc=92.66%
# ✅ Saved model: Model_92_66_Epoch135.pt (Val Acc: 92.66%)
# Epoch 136: Loss=0.91, Train Acc=99.94%, Val Acc=92.77%
# ✅ Saved model: Model_92_77_Epoch136.pt (Val Acc: 92.77%)
# Epoch 137: Loss=1.15, Train Acc=99.91%, Val Acc=92.89%
# ✅ Saved model: Model_92_89_Epoch137.pt (Val Acc: 92.89%)
# Epoch 138: Loss=0.75, Train Acc=100.00%, Val Acc=93.12%
# ✅ Saved model: Model_93_12_Epoch138.pt (Val Acc: 93.12%)
# Epoch 139: Loss=0.83, Train Acc=99.97%, Val Acc=92.89%
# ✅ Saved model: Model_92_89_Epoch139.pt (Val Acc: 92.89%)
# Epoch 140: Loss=0.89, Train Acc=99.95%, Val Acc=92.66%
# ✅ Saved model: Model_92_66_Epoch140.pt (Val Acc: 92.66%)
# Epoch 141: Loss=0.94, Train Acc=99.97%, Val Acc=92.42%
# ✅ Saved model: Model_92_42_Epoch141.pt (Val Acc: 92.42%)
# Epoch 142: Loss=0.86, Train Acc=99.96%, Val Acc=92.42%
# ✅ Saved model: Model_92_42_Epoch142.pt (Val Acc: 92.42%)
# Epoch 143: Loss=0.99, Train Acc=99.95%, Val Acc=92.66%
# ✅ Saved model: Model_92_66_Epoch143.pt (Val Acc: 92.66%)
# Epoch 144: Loss=0.84, Train Acc=99.94%, Val Acc=92.66%
# ✅ Saved model: Model_92_66_Epoch144.pt (Val Acc: 92.66%)
# Epoch 145: Loss=1.04, Train Acc=99.95%, Val Acc=92.89%
# ✅ Saved model: Model_92_89_Epoch145.pt (Val Acc: 92.89%)
# Epoch 146: Loss=0.87, Train Acc=99.97%, Val Acc=92.77%
# ✅ Saved model: Model_92_77_Epoch146.pt (Val Acc: 92.77%)
# Epoch 147: Loss=0.95, Train Acc=99.94%, Val Acc=93.12%
# ✅ Saved model: Model_93_12_Epoch147.pt (Val Acc: 93.12%)
# Epoch 148: Loss=0.75, Train Acc=99.97%, Val Acc=92.54%
# ✅ Saved model: Model_92_54_Epoch148.pt (Val Acc: 92.54%)
# Epoch 149: Loss=0.81, Train Acc=99.97%, Val Acc=92.54%
# ✅ Saved model: Model_92_54_Epoch149.pt (Val Acc: 92.54%)
# Epoch 150: Loss=1.03, Train Acc=99.91%, Val Acc=92.42%
# ✅ Saved model: Model_92_42_Epoch150.pt (Val Acc: 92.42%)
# Epoch 151: Loss=0.75, Train Acc=99.97%, Val Acc=92.31%
# ✅ Saved model: Model_92_31_Epoch151.pt (Val Acc: 92.31%)
# Epoch 152: Loss=0.82, Train Acc=99.96%, Val Acc=92.54%
# ✅ Saved model: Model_92_54_Epoch152.pt (Val Acc: 92.54%)
# Epoch 153: Loss=0.87, Train Acc=99.94%, Val Acc=92.66%
# ✅ Saved model: Model_92_66_Epoch153.pt (Val Acc: 92.66%)
# Epoch 154: Loss=0.71, Train Acc=100.00%, Val Acc=92.77%
# ✅ Saved model: Model_92_77_Epoch154.pt (Val Acc: 92.77%)
# Epoch 155: Loss=0.74, Train Acc=99.97%, Val Acc=92.77%
# ✅ Saved model: Model_92_77_Epoch155.pt (Val Acc: 92.77%)
# Epoch 156: Loss=0.74, Train Acc=99.96%, Val Acc=92.77%
# ✅ Saved model: Model_92_77_Epoch156.pt (Val Acc: 92.77%)
# Epoch 157: Loss=0.82, Train Acc=99.92%, Val Acc=92.66%
# ✅ Saved model: Model_92_66_Epoch157.pt (Val Acc: 92.66%)
# Epoch 158: Loss=0.85, Train Acc=99.96%, Val Acc=92.66%
# ✅ Saved model: Model_92_66_Epoch158.pt (Val Acc: 92.66%)
# Epoch 159: Loss=0.80, Train Acc=99.97%, Val Acc=92.77%
# ✅ Saved model: Model_92_77_Epoch159.pt (Val Acc: 92.77%)
# Epoch 160: Loss=0.78, Train Acc=99.96%, Val Acc=92.66%
# ✅ Saved model: Model_92_66_Epoch160.pt (Val Acc: 92.66%)
# Epoch 161: Loss=0.82, Train Acc=99.96%, Val Acc=92.42%
# ✅ Saved model: Model_92_42_Epoch161.pt (Val Acc: 92.42%)
# Epoch 162: Loss=0.72, Train Acc=99.97%, Val Acc=92.77%
# ✅ Saved model: Model_92_77_Epoch162.pt (Val Acc: 92.77%)
# Epoch 163: Loss=0.75, Train Acc=99.94%, Val Acc=92.77%
# ✅ Saved model: Model_92_77_Epoch163.pt (Val Acc: 92.77%)
# Epoch 164: Loss=0.70, Train Acc=99.97%, Val Acc=92.77%
# ✅ Saved model: Model_92_77_Epoch164.pt (Val Acc: 92.77%)
# Epoch 165: Loss=0.77, Train Acc=99.99%, Val Acc=92.66%
# ✅ Saved model: Model_92_66_Epoch165.pt (Val Acc: 92.66%)
# Epoch 166: Loss=0.71, Train Acc=99.97%, Val Acc=92.66%
# ✅ Saved model: Model_92_66_Epoch166.pt (Val Acc: 92.66%)
# Epoch 167: Loss=0.81, Train Acc=99.92%, Val Acc=92.66%
# ✅ Saved model: Model_92_66_Epoch167.pt (Val Acc: 92.66%)
# Epoch 168: Loss=0.77, Train Acc=99.95%, Val Acc=92.54%
# ✅ Saved model: Model_92_54_Epoch168.pt (Val Acc: 92.54%)
# Epoch 169: Loss=0.68, Train Acc=99.96%, Val Acc=92.66%
# ✅ Saved model: Model_92_66_Epoch169.pt (Val Acc: 92.66%)
# Epoch 170: Loss=0.64, Train Acc=99.97%, Val Acc=92.77%
# ✅ Saved model: Model_92_77_Epoch170.pt (Val Acc: 92.77%)
# Epoch 171: Loss=0.75, Train Acc=99.99%, Val Acc=92.54%
# ✅ Saved model: Model_92_54_Epoch171.pt (Val Acc: 92.54%)
# Epoch 172: Loss=0.85, Train Acc=99.94%, Val Acc=92.77%
# ✅ Saved model: Model_92_77_Epoch172.pt (Val Acc: 92.77%)
# Epoch 173: Loss=0.64, Train Acc=99.95%, Val Acc=92.77%
# ✅ Saved model: Model_92_77_Epoch173.pt (Val Acc: 92.77%)
# Epoch 174: Loss=0.62, Train Acc=99.99%, Val Acc=92.54%
# ✅ Saved model: Model_92_54_Epoch174.pt (Val Acc: 92.54%)
# Epoch 175: Loss=0.70, Train Acc=99.97%, Val Acc=92.66%
# ✅ Saved model: Model_92_66_Epoch175.pt (Val Acc: 92.66%)
# Epoch 176: Loss=0.74, Train Acc=99.99%, Val Acc=92.54%
# ✅ Saved model: Model_92_54_Epoch176.pt (Val Acc: 92.54%)
# Epoch 177: Loss=0.71, Train Acc=99.95%, Val Acc=92.89%
# ✅ Saved model: Model_92_89_Epoch177.pt (Val Acc: 92.89%)
# Epoch 178: Loss=0.59, Train Acc=100.00%, Val Acc=92.66%
# ✅ Saved model: Model_92_66_Epoch178.pt (Val Acc: 92.66%)
# Epoch 179: Loss=0.62, Train Acc=99.97%, Val Acc=92.42%
# ✅ Saved model: Model_92_42_Epoch179.pt (Val Acc: 92.42%)
# Epoch 180: Loss=0.64, Train Acc=99.99%, Val Acc=92.77%
# ✅ Saved model: Model_92_77_Epoch180.pt (Val Acc: 92.77%)
# Epoch 181: Loss=0.67, Train Acc=99.96%, Val Acc=92.54%
# ✅ Saved model: Model_92_54_Epoch181.pt (Val Acc: 92.54%)
# Epoch 182: Loss=0.81, Train Acc=99.96%, Val Acc=92.54%
# ✅ Saved model: Model_92_54_Epoch182.pt (Val Acc: 92.54%)
# Epoch 183: Loss=0.79, Train Acc=99.95%, Val Acc=92.66%
# ✅ Saved model: Model_92_66_Epoch183.pt (Val Acc: 92.66%)
# Epoch 184: Loss=0.61, Train Acc=99.97%, Val Acc=92.66%
# ✅ Saved model: Model_92_66_Epoch184.pt (Val Acc: 92.66%)
# Epoch 185: Loss=0.61, Train Acc=99.99%, Val Acc=92.66%
# ✅ Saved model: Model_92_66_Epoch185.pt (Val Acc: 92.66%)
# Epoch 186: Loss=0.71, Train Acc=99.96%, Val Acc=92.77%
# ✅ Saved model: Model_92_77_Epoch186.pt (Val Acc: 92.77%)
# Epoch 187: Loss=0.55, Train Acc=100.00%, Val Acc=92.66%
# ✅ Saved model: Model_92_66_Epoch187.pt (Val Acc: 92.66%)
# Epoch 188: Loss=0.94, Train Acc=99.91%, Val Acc=92.77%
# ✅ Saved model: Model_92_77_Epoch188.pt (Val Acc: 92.77%)
# Epoch 189: Loss=0.70, Train Acc=99.96%, Val Acc=92.77%
# ✅ Saved model: Model_92_77_Epoch189.pt (Val Acc: 92.77%)
# Epoch 190: Loss=0.65, Train Acc=99.97%, Val Acc=92.66%
# ✅ Saved model: Model_92_66_Epoch190.pt (Val Acc: 92.66%)
# Epoch 191: Loss=0.69, Train Acc=99.95%, Val Acc=92.77%
# ✅ Saved model: Model_92_77_Epoch191.pt (Val Acc: 92.77%)
# Epoch 192: Loss=0.82, Train Acc=99.97%, Val Acc=92.77%
# ✅ Saved model: Model_92_77_Epoch192.pt (Val Acc: 92.77%)
# Epoch 193: Loss=0.53, Train Acc=99.99%, Val Acc=92.77%
# ✅ Saved model: Model_92_77_Epoch193.pt (Val Acc: 92.77%)
# Epoch 194: Loss=0.54, Train Acc=99.95%, Val Acc=92.77%
# ✅ Saved model: Model_92_77_Epoch194.pt (Val Acc: 92.77%)
# Epoch 195: Loss=0.78, Train Acc=99.95%, Val Acc=92.77%
# ✅ Saved model: Model_92_77_Epoch195.pt (Val Acc: 92.77%)
# Epoch 196: Loss=1.01, Train Acc=99.92%, Val Acc=92.77%
# ✅ Saved model: Model_92_77_Epoch196.pt (Val Acc: 92.77%)
# Epoch 197: Loss=0.90, Train Acc=99.96%, Val Acc=92.77%
# ✅ Saved model: Model_92_77_Epoch197.pt (Val Acc: 92.77%)
# Epoch 198: Loss=0.57, Train Acc=99.96%, Val Acc=92.89%
# ✅ Saved model: Model_92_89_Epoch198.pt (Val Acc: 92.89%)
# Epoch 199: Loss=0.61, Train Acc=99.97%, Val Acc=92.66%
# ✅ Saved model: Model_92_66_Epoch199.pt (Val Acc: 92.66%)
# Epoch 200: Loss=0.63, Train Acc=99.95%, Val Acc=92.77%
# ✅ Saved model: Model_92_77_Epoch200.pt (Val Acc: 92.77%)
#
# ✅ Final Test Accuracy: 93.20%
